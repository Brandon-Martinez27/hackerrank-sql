# %% [markdown]
# # Weather Observation Station 11
#
# Query the list of CITY names from STATION that either do not start with vowels or do not end with vowels. Your result cannot contain duplicates.
#
# Input Format
#
# The STATION table is described as follows

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/9336/1449345840-5f0a551030-Station.jpg")

# %% [markdown]
# where LAT_N is the northern latitude and LONG_W is the western longitude.

# %%
print('''Query: \n
SELECT DISTINCT CITY
FROM STATION
WHERE substr(CITY,1,1)  NOT in ('A','E','I','O','U')
    OR substr(CITY,-1,1)  NOT in ('a','e','i','o','u');
''')
# Out:
# Query:
#
# SELECT DISTINCT CITY
# FROM STATION
# WHERE substr(CITY,1,1)  NOT in ('A','E','I','O','U')
#     OR substr(CITY,-1,1)  NOT in ('a','e','i','o','u');

# %% [markdown]
# #### Result
# Addison
# Agency
# Alanson
# Albany
# Albion
# Algonac
# Allerton
# Alton
# Andover
# Anthony
# Arlington
# (truncated)

# %% [markdown]
# ---
# # Weather Observation Station 12
#
# Query the list of CITY names from STATION that do not start with vowels and do not end with vowels. Your result cannot contain duplicates.
#
# Input Format
#
# The STATION table is described as follows:

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/9336/1449345840-5f0a551030-Station.jpg")

# %% [markdown]
# where LAT_N is the northern latitude and LONG_W is the western longitude.

# %%
print('''Query: \n
SELECT DISTINCT CITY
FROM STATION
WHERE substr(CITY,1,1)  NOT in ('A','E','I','O','U')
    AND substr(CITY,-1,1)  NOT in ('a','e','i','o','u');
''')
# Out:
# Query:
#
# SELECT DISTINCT CITY
# FROM STATION
# WHERE substr(CITY,1,1)  NOT in ('A','E','I','O','U')
#     AND substr(CITY,-1,1)  NOT in ('a','e','i','o','u');

# %% [markdown]
# #### Result
# Baker
# Baldwin
# Bass Harbor
# Beaufort
# Beaver Island
# Benedict
# Bennington
# Berryton
# Beverly
#
# (truncated)

# %% [markdown]
# ---
# # Higher Than 75 Marks
#
# Query the Name of any student in STUDENTS who scored higher than 75 Marks. Order your output by the last three characters of each name. If two or more students both have names ending in the same last three characters (i.e.: Bobby, Robby, etc.), secondary sort them by ascending ID.
#
# Input Format

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/12896/1443815243-94b941f556-1.png")

# %% [markdown]
# The STUDENTS table is described as follows:
#
# The Name column only contains uppercase (A-Z) and lowercase (a-z) letters.
#
# Sample Input

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/12896/1443815209-cf4b260993-2.png")

# %% [markdown]
# Sample Output
#
# Ashley
# Julia
# Belvet
#
# Explanation
#
# Only Ashley, Julia, and Belvet have Marks > 75. If you look at the last three characters of each of their names, there are no duplicates and 'ley' < 'lia' < 'vet'.

# %%
print('''Query: \n
SELECT Name
FROM STUDENTS
WHERE Marks > 75
ORDER BY substr(Name, -3, 3), ID;
''')
# Out:
# Query:
#
# SELECT Name
# FROM STUDENTS
# WHERE Marks > 75
# ORDER BY substr(Name, -3, 3), ID;

# %% [markdown]
# #### Result
# Stuart
# Kristeen
# Christene
# Amina
# Aamina
# Priya
# Heraldo
# Scarlet
# Julia
# Salma
# Britney
# Priyanka
# Samantha
# Vivek
# Belvet
# Devil
# Evil

# %% [markdown]
# ---
# # Employee Names
#
# Write a query that prints a list of employee names (i.e.: the name attribute) from the Employee table in alphabetical order.
#
# Input Format
#
# The Employee table containing employee data for a company is described as follows:

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/19629/1458557872-4396838885-ScreenShot2016-03-21at4.27.13PM.png")

# %% [markdown]
# where employee_id is an employee's ID number, name is their name, months is the total number of months they've been working for the company, and salary is their monthly salary.
#
# Sample Input

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/19629/1458558202-9a8721e44b-ScreenShot2016-03-21at4.32.59PM.png")

# %% [markdown]
# Sample Output
#
# Angela
# Bonnie
# Frank
# Joe
# Kimberly
# Lisa
# Michael
# Patrick
# Rose
# Todd

# %%
print('''Query: \n
SELECT name
FROM Employee
ORDER BY name;
''')
# Out:
# Query:
#
# SELECT name
# FROM Employee
# ORDER BY name;

# %% [markdown]
# #### Result
# Alan
# Amy
# Andrew
# Andrew
# Angela
# Ann
# Anna
# Anthony
# Antonio
# Benjamin
# (truncated)

# %% [markdown]
# ---
# # Employee Salaries
#
# Write a query that prints a list of employee names (i.e.: the name attribute) for employees in Employee having a salary greater than \$2000 per month who have been employees for less than 10 months. Sort your result by ascending employee_id.
#
# Input Format
#
# The Employee table containing employee data for a company is described as follows:

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/19629/1458557872-4396838885-ScreenShot2016-03-21at4.27.13PM.png")

# %% [markdown]
# where employee_id is an employee's ID number, name is their name, months is the total number of months they've been working for the company, and salary is their monthly salary.
#
# Sample Input

# %%
from IPython import display 
display.Image("https://s3.amazonaws.com/hr-challenge-images/19629/1458558202-9a8721e44b-ScreenShot2016-03-21at4.32.59PM.png")

# %% [markdown]
# Sample Output
#
# Angela
# Michael
# Todd
# Joe
#
# Explanation
#
# Angela has been an employee for 1 month and earns \$3443 per month.
#
# Michael has been an employee for 6 months and earns \$2017 per month.
#
# Todd has been an employee for 5 months and earns \$3396 per month.
#
# Joe has been an employee for 9 months and earns \$3573 per month.
#
# We order our output by ascending employee_id.

# %%
print('''Query: \n
SELECT name
FROM Employee
WHERE salary > 2000
    AND months < 10
ORDER BY employee_id
''')
# Out:
# Query:
#
# SELECT name
# FROM Employee
# WHERE salary > 2000
#     AND months < 10
# ORDER BY employee_id

# %% [markdown]
# #### Result
# Rose
# Patrick
# Lisa
# Amy
# Pamela
# Jennifer
# Julia
# Kevin
# Paul
# Donna
# Michelle
# Christina
# Brandon
# Joseph
# Jesse
# Paula
# Louise
# Evelyn
# Emily
# Jonathan
# Nancy
# Benjamin
# Roy
# Diana
# Christine
